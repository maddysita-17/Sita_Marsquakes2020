# %%
import matplotlib.pyplot as plt
import numpy as np
import obspy

from obspy.imaging.beachball import beachball
from obspy.imaging.beachball import beach
from obspy.imaging.source import plot_radiation_pattern

# %%
def getmt(fault):
    rad = 180./np.pi; m0 = 1
    st,dp,rk = fault

    st = st/rad; dp = dp/rad; rk = rk/rad
    sd = np.sin(dp); cd = np.cos(dp)
    sd2 = np.sin(2*dp); cd2 = np.cos(2*dp)
    ss = np.sin(st); cs = np.cos(st)
    ss2 = np.sin(2*st); cs2 = np.cos(2*st)
    sr = np.sin(rk); cr = np.cos(rk)

    # formulas from Aki & Richards Box 4.4
    # mt(1-6): Mrr, Mtt, Mff, Mrt, Mrf, Mtf
    # mt(1-6): Mzz, Mxx, Myy, Mzx, -Mzy, -Mxy
    mt = [ sr*sd2, -1.*sd*cr*ss2 - sd2*sr*ss*ss, sd*cr*ss2 - sd2*sr*cs*cs, -1.*cd*cr*cs - cd2*sr*ss, cd*cr*ss - cd2*sr*cs, -1.*sd*cr*cs2 - 0.5*sd2*sr*ss2]
    return mt

# %%
#(strike, dip, and rake)
s0173a = [150, 60, 80]
fig173a = beachball(s0173a)
mt173a = getmt(s0173a)
plot_radiation_pattern(mt173a, kind=['beachball']);

# %%
s0235b = [130, 90, -90]
fig235b = beachball(s0235b)
mt235b = getmt(s0235b)
plot_radiation_pattern(mt235b, kind=['beachball']);

# %%
s0325a = [45, 90, -90]
fig325a = beachball(s0325a)
mt325a = getmt(s0325a)
plot_radiation_pattern(mt325a, kind=['beachball']);

# %%
s0325ab = [90, 80, 90]
fig325ab = beachball(s0325ab)
mt325ab = getmt(s0325ab)
plot_radiation_pattern(mt325ab, kind=['beachball']);
