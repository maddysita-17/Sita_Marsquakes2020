# %%
import matplotlib.pyplot as plt
import numpy as np
import obspy
import pandas as pd

from obspy.imaging.beachball import beachball
from obspy.imaging.beachball import beach
from obspy.imaging.source import plot_radiation_pattern

# %%
def bbplot(file, event, alpha = 0.1):
    path = '/Users/maddysita/Desktop/CIERA_REU/script_notebooks/beachballs/csvs/'
    faults = pd.read_csv(path + str(file), usecols=[0,1,2])

    faults_ls =[]

    for index, rows in faults.iterrows():
        my_list =[rows.Strike, rows.Dip, rows.Rake]
        faults_ls.append(my_list)
    
    n = 0
    for fault in faults_ls:
        if n == 0:
            fig = beachball(fault, alpha = alpha, edgecolor = None)

        else:
            fig2 = beachball(fault, alpha = alpha, edgecolor = None, fig=fig)
        n += 1
        
    fig.patch.set_visible(False)
    plt.savefig('mf3d_' + event + '.png')
    return

# %%
def sep_bbplot(data, event, alpha = 0.1):
    faults = data.loc[:,['Strike','Dip', 'Rake']]
    
    faults_ls = []
    
    for index, rows in faults.iterrows():
        my_list =[rows.Strike, rows.Dip, rows.Rake]
        faults_ls.append(my_list)
    
    n = 0
    for f in faults_ls:
        if n == 0:
            fig = beachball(f, alpha = alpha, edgecolor = None)

        else:
            fig2 = beachball(f, alpha=alpha, edgecolor = None, fig=fig)
        n += 1
    
    fig.patch.set_visible(False)
    plt.savefig(event + '.png')
    return

# %% [markdown]
# # S0173a

# %%
# %matplotlib notebook
bbplot('trail_S0173a.csv', 'S0173a')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">
# /anaconda3/envs/REU2020/lib/python3.7/site-packages/obspy/imaging/beachball.py:254: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(111, aspect='equal')

# %%
# %matplotlib notebook
bbplot('mf3d_S0173a.csv', 'S0173a')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">
# /anaconda3/envs/REU2020/lib/python3.7/site-packages/obspy/imaging/beachball.py:254: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(111, aspect='equal')

# %%
s0173a = pd.read_csv('S0173a.csv')
df1 = s0173a[s0173a['Dip'] < 35]

df23 = s0173a[s0173a['Dip'] >= 35]
df2 = df23[df23['Strike'] < 160]
df3 = df23[df23['Strike'] >= 160 ]

print(len(df3))

vframes = [df1, df2]
vertdf = pd.concat(vframes)

print(len(vertdf))

sep_bbplot(vertdf, 'S0173a-stslp')
# Out:
# 15
# 81
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
reversed_df = df3.iloc[::-1]
sep_bbplot(reversed_df, 'S0173a-normal')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %% [markdown]
# # S0235b

# %%
# %matplotlib notebook
bbplot('S0235b.csv', 'S0235b')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
bbplot('mf3d_S0235b.csv', 'S0235b')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
s0235b = pd.read_csv('S0235b.csv')

df = s0235b[s0235b['Dip'] >= 20]
dfvert = df[df['Dip'] >= 80]

dfnorm2 = s0235b[s0235b['Dip'] <= 20]

reversed_df = dfnorm2.iloc[::-1]
sep_bbplot(dfnorm2, 'S0235b-norm')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
sep_bbplot(dfvert, 'S0235b-vert')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %% [markdown]
# # S0235bi

# %%
bbplot('S0235bi.csv', 'S0235bi')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
s0235bi = pd.read_csv('S0235bi.csv')

dfstslp = s0235bi[s0235bi['Strike'] >= 95]
stslp = dfstslp[dfstslp['Strike'] <= 145]

sep_bbplot(stslp, 'S0235bi-stslp')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
dfvert1 = s0235bi[s0235bi['Strike']<=10]
dfvert2 = s0235bi[s0235bi['Strike']>=155]

vertframes = [dfvert1, dfvert]
vert = pd.concat(vertframes)
sep_bbplot(vert, 'S0235bi-vert')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %% [markdown]
# # S0325a

# %%
bbplot('S0325a.csv', 'S0325a')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
bbplot('mf3d_S0325a.csv', 'S0325a')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
s0325a = pd.read_csv('S0325a.csv')
vert = s0325a[s0325a['Dip'] < 15]

sep_bbplot(vert, 'S0325a-vert', alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
stksp = s0325a[s0325a['Dip'] >= 15]
sep_bbplot(stksp, 'S0325a-sksp', alpha = 0.3)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %% [markdown]
# # S0325ab

# %%
bbplot('S0325ab.csv', 'S0325ab', alpha = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
bbplot('mf3d_S0325ab.csv', 'S0325ab')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %% [markdown]
# # S0173ab

# %%
bbplot('S0173ab.csv', 'S0173ab')
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
bbplot('mf3d_S0173ab.csv', 'S0173ab')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-14-62153213f695> in <module>
# ----> 1 bbplot('mf3d_S0173ab.csv', 'S0173ab')
#
# <ipython-input-9-82f19671d874> in bbplot(file, event, alpha)
#      18         n += 1
#      19
# ---> 20     fig.patch.set_visible(False)
#      21     #plt.savefig(event + '.png')
#      22     return
#
# UnboundLocalError: local variable 'fig' referenced before assignment

# %%
s0173ab = pd.read_csv('S0173ab.csv')

stsp = s0173ab[s0173ab['Strike'] >= 45]
stsp1 = stsp[stsp['Strike'] <=65 ]

sep_bbplot(stsp1, 'S0173ab-stsp1', alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
stsp = s0173ab[s0173ab['Strike'] >= 20]
stsp1 = stsp[stsp['Strike'] <=35 ]

sep_bbplot(stsp1, 'S0173ab-stsp2', alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
stsp = s0173ab[s0173ab['Rake'] == -100]

sep_bbplot(stsp, 'S0173ab-norm', alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
stsp = s0173ab[s0173ab['Rake'] == 80]

sep_bbplot(stsp, 'S0173ab-thrust', alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">

# %%
st1 = s0173ab[s0173ab['Strike'] == 140]
st2 = s0173ab[s0173ab['Strike'] == 175]

frames = [st1, st2]
stsp = pd.concat(frames)
sep_bbplot(stsp, 'S0173ab-stsp3', alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="199.44444972791803">
