# %%
import obspy
import obspy.taup
from obspy.taup.tau_model import TauModel
from obspy.taup.taup_create import build_taup_model
from obspy.taup import TauPyModel
from obspy.taup.taup_time import TauPTime
from obspy.taup import plot_travel_times
import matplotlib.pyplot as plt

# %%
Gudkova = TauPyModel(model="Gudkova")
model = Gudkova

# %%
tt = TauPTime(model = "Gudkova", phase_list=['P', 'S'], depth = 25, degrees = 30)

# %%
print(tt)
# Out:
# <obspy.taup.taup_time.TauPTime object at 0x1a18632490>

# %%
for dist in [10,20,30,40,50]:
    arrivals = model.get_ray_paths(phase_list=["P", "S"], source_depth_in_km=20,
                               distance_in_degree=dist)
    ax = arrivals.plot_times()
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
# %matplotlib notebook

fig, ax = plt.subplots(figsize=(9, 9))
ax = plot_travel_times(source_depth=10, phase_list=["P"],ax=ax, fig=fig)
# Out:
# <img src="data:image/png;base64,..." width="899.4444682715858">
