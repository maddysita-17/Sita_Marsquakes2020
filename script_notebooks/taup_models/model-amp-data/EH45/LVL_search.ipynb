# %%
import matplotlib.pyplot as plt
import numpy as np
from obspy.taup import TauPyModel
import pandas as pd

# %%
# EH45: 235b @ 45km
radius = 3389.5
mars = TauPyModel(model="EH45Tcold")
mtimes = mars.get_travel_times(source_depth_in_km=45, distance_in_degree=27.5, phase_list=["P", "S"])
print(mars.model_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-dbfc63a19db3> in <module>
#       3 mars = TauPyModel(model="EH45Tcold")
#       4 mtimes = mars.get_travel_times(source_depth_in_km=45, distance_in_degree=27.5, phase_list=["P", "S"])
# ----> 5 print(mars.model_name)
#
# AttributeError: 'TauPyModel' object has no attribute 'model_name'

# %%
# %matplotlib notebook
arrivals = mars.get_ray_paths(
    source_depth_in_km=45, distance_in_degree=27.5, phase_list=["P", "S"])
ax = arrivals.plot_rays()
ax = arrivals.plot_rays(plot_type='cartesian')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
# %matplotlib notebook
arrivals = mars.get_ray_paths(
    source_depth_in_km=55, distance_in_degree=27.5, phase_list=["P", "S"])
ax = arrivals.plot_rays()
ax = arrivals.plot_rays(plot_type='cartesian')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
# LFAK: 235b @ 25km
radius = 3389.5
mars = TauPyModel(model="LFAK")
mtimes = mars.get_travel_times(source_depth_in_km=25, distance_in_degree=27.5, phase_list=["P", "S"])

# %%
# %matplotlib notebook
arrivals = mars.get_ray_paths(
    source_depth_in_km=25, distance_in_degree=27.5, phase_list=["P", "S"])
ax = arrivals.plot_rays()
ax = arrivals.plot_rays(plot_type='cartesian')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
# %matplotlib notebook
arrivals = mars.get_ray_paths(
    source_depth_in_km=35, distance_in_degree=27.5, phase_list=["P", "S"])
ax = arrivals.plot_rays()
ax = arrivals.plot_rays(plot_type='cartesian')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# <img src="data:image/png;base64,..." width="639.4444613839378">
